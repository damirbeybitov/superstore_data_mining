# %% [markdown]
# ## Import

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel('Global Superstore Data.xlsx')
df
# Out:
#        Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# 0       24599   IN-2017-CA120551-42816 2017-03-22 2017-03-29  Standard Class
# 1       29465   ID-2015-BD116051-42248 2015-09-01 2015-09-04    Second Class
# 2       24598   IN-2017-CA120551-42816 2017-03-22 2017-03-29  Standard Class
# 3       24597   IN-2017-CA120551-42816 2017-03-22 2017-03-29  Standard Class
# 4       29464   ID-2015-BD116051-42248 2015-09-01 2015-09-04    Second Class
# ...       ...                      ...        ...        ...             ...
# 51285   46231   ZA-2014-AS285147-41718 2014-03-20 2014-03-25  Standard Class
# 51286   50122  ZA-2017-HG4965147-42876 2017-05-21 2017-05-23    Second Class
# 51287   50297  ZA-2016-EB3870147-42499 2016-05-09 2016-05-15  Standard Class
# 51288   47164  ZA-2015-JG5115147-42040 2015-02-05 2015-02-10  Standard Class
# 51289   47557  ZA-2016-ND8460147-42400 2016-01-31 2016-02-05    Second Class
#
# ...

# %%
returns = pd.read_excel('Global Superstore Data.xlsx', sheet_name='Returns')
returns
# Out:
#      Returned                  Order ID          Region
# 0         Yes    IN-2017-CA120551-42816   Southern Asia
# 1         Yes    IN-2017-AA103751-42926   Southern Asia
# 2         Yes    IN-2017-TS212051-42904   Southern Asia
# 3         Yes     AG-2014-RO97803-41695    North Africa
# 4         Yes     AG-2015-LC70503-42265    North Africa
# ...       ...                       ...             ...
# 2028      Yes   ZA-2017-BT1395147-43067  Eastern Africa
# 2029      Yes  ZA-2016-TH11235147-42444  Eastern Africa
# 2030      Yes   ZA-2015-DN3690147-42159  Eastern Africa
# 2031      Yes  ZA-2016-TH11235147-42444  Eastern Africa
# 2032      Yes   ZA-2015-LC6885147-42021  Eastern Africa
#
# [2033 rows x 3 columns]

# %%
df = df.merge(returns.drop('Region', axis=1), how='left', on='Order ID')
df
# Out:
#        Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# 0       24599   IN-2017-CA120551-42816 2017-03-22 2017-03-29  Standard Class
# 1       29465   ID-2015-BD116051-42248 2015-09-01 2015-09-04    Second Class
# 2       24598   IN-2017-CA120551-42816 2017-03-22 2017-03-29  Standard Class
# 3       24597   IN-2017-CA120551-42816 2017-03-22 2017-03-29  Standard Class
# 4       29464   ID-2015-BD116051-42248 2015-09-01 2015-09-04    Second Class
# ...       ...                      ...        ...        ...             ...
# 51588   46231   ZA-2014-AS285147-41718 2014-03-20 2014-03-25  Standard Class
# 51589   50122  ZA-2017-HG4965147-42876 2017-05-21 2017-05-23    Second Class
# 51590   50297  ZA-2016-EB3870147-42499 2016-05-09 2016-05-15  Standard Class
# 51591   47164  ZA-2015-JG5115147-42040 2015-02-05 2015-02-10  Standard Class
# 51592   47557  ZA-2016-ND8460147-42400 2016-01-31 2016-02-05    Second Class
#
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Product Name',
#        'Sub-Category', 'Category', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Cost', 'Order Priority', 'Returned'],
#       dtype='object')

# %%
col_to_drop = ['Customer ID', 'Customer Name']
ids = ['Row ID', 'Order ID', 'Product ID']

# %%
df_grouped = (
    df.groupby(['Region', 'Country', 'State', 'City'])['Sales']
      .sum()
      .reset_index()
)
df_grouped
# Out:
#           Region        Country             State        City       Sales
# 0         Canada         Canada           Alberta     Calgary    3063.030
# 1         Canada         Canada           Alberta    Edmonton    3360.030
# 2         Canada         Canada           Alberta    Red Deer     127.800
# 3         Canada         Canada  British Columbia  Abbotsford     295.740
# 4         Canada         Canada  British Columbia     Burnaby     855.030
# ...          ...            ...               ...         ...         ...
# 3823  Western US  United States        Washington      Renton    1242.632
# 3824  Western US  United States        Washington     Seattle  123751.392
# 3825  Western US  United States        Washington     Spokane    2027.918
# 3826  Western US  United States        Washington   Vancouver     686.836
# 3827  Western US  United States           Wyoming    Cheyenne    1603.136
#
# [3828 rows x 5 columns]

# %%
df_grouped.to_excel('text.xlsx', index=False)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Product Name',
#        'Sub-Category', 'Category', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Cost', 'Order Priority'],
#       dtype='object')
